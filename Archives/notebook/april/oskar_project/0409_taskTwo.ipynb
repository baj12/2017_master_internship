# %% [markdown]
# # taskTwo
# ## Analyzing HMM results
#
# _Date: 04/09/2017_

# %%
import pandas as pd

# %%
df = pd.read_table('oskar_result.txt')

# %%
len(df)
# Out:
# 50

# %%
df.set_index('tsa')
df.sort_values('organism')
# Out:
#        tsa                    organism  \
# 32  GCZT.1            Aedes albopictus
# 31  GCLM.1            Aedes albopictus
# 2   GACZ.1         Anopheles aquasalis
# 29  GBVY.1         Anopheles aquasalis
# 13  GAMD.1         Anopheles aquasalis
# 28  GBTE.1   Anopheles quadrimaculatus
# 24  GBBQ.1          Anopheles sinensis
# 25  GBEO.1          Anopheles sinensis
# 36  GDKS.1          Anopheles sinensis
# 37  GDQV.1       Arachnocampa luminosa
# 30  GBXI.1       Bactrocera cucurbitae
# 9   GAKP.1         Bactrocera dorsalis
# 38  GDRP.1         Bactrocera dorsalis
# 41  GEEA.1         Bactrocera dorsalis
# 33  GDAI.1        Bactrocera latifrons
# 34  GDHF.1        Bactrocera latifrons
# 16  GATI.1             Bombylius major
# 12  GAMC.1          Ceratitis capitata
# 14  GANO.1   Corethrella appendiculata
# 48  GFDL.1              Culex tarsalis
# 45  GEYS.1       Culicoides sonorensis
# 19  GAWM.1       Culicoides sonorensis
# 20  GAXZ.1       Culicoides sonorensis
# 46  GFDF.1               Delia antiqua
# 4   GADP.1         Drosophila ercepeae
# 1   GABS.1    Drosophila malerkotliana
# 3   GADM.1    Drosophila malerkotliana
# 11  GALP.1          Drosophila miranda
# 17  GATJ.1          Drosophila miranda
# 7   GAKB.1          Drosophila montana
# 40  GECM.1          Drosophila montana
# 5   GAEJ.1  Drosophila pseudoananassae
# 6   GAHN.1          Drosophila serrata
# 10  GALA.1          Drosophila serrata
# 27  GBRX.1           Glossina palpalis
# 43  GEMK.1       Liogma simplicicornis
# 21  GAZD.1               Lipara lucens
# 0   GAAP.1             Musca domestica
# 22  GBAB.1             Musca domestica
# 49  HACL.1             Musca domestica
# 42  GEMI.1             Pedicia vetusta
# 15  GAPW.1        Rhagoletis pomonella
# 47  GFDG.1        Rhagoletis pomonella
# 26  GBRL.1      Sitodiplosis mosellana
# 8   GAKJ.1      Sitodiplosis mosellana
# 35  GDIM.1         Stomoxys calcitrans
# 39  GDUN.1          Teleopsis dalmanni
# 23  GBBP.1          Teleopsis dalmanni
# 44  GEVJ.1              Themira biloba
# 18  GAVA.1       Triarthria setipennis
#
#                                        oskar_sequence oskar
# 32                              GCZT01003075.1_4        yes
# 31                              GCLM01061907.1_6        yes
# 2                                                 NaN    no
# 29                                                NaN    no
# 13                              GAMD01000859.1_1        yes
# 28                              GBTE01009320.1_1        yes
# 24                                                NaN    no
# 25                              GBEO01001325.1_3        yes
# 36         GDKS01031624.1_4     GDKS01033996.1_6        yes
# 37         GDQV01038263.1_3     GDQV01038264.1_3        yes
# 30                              GBXI01000635.1_2        yes
# 9                               GAKP01002609.1_2        yes
# 38                                                NaN    no
# 41                              GEEA01014764.1_2        yes
# 33                                                NaN    no
# 34  GDHF01029687.1_1     GDHF01014032.1_1     GDHF...   yes
# 16                              GATI02024491.1_3        yes
# 12         GAMC01000911.1_1     GAMC01000912.1_1        yes
# 14                              GANO01003814.1_1        yes
# 48  GFDL01015869.1_1     GFDL01015870.1_1     GFDL...   yes
# 45                                                NaN    no
# 19                              GAWM01006639.1_1        yes
# 20                                                NaN    no
# 46                                                NaN    no
# 4                                                 NaN    no
# 1                                                 NaN    no
# 3                               GADM01000016.1_5        yes
# 11                              GALP01010973.1_3        yes
# 17                                                NaN    no
# 7                                                 NaN    no
# 40                              GECM01023295.1_1        yes
# 5                                                 NaN    no
# 6                               GAHN01005171.1_6        yes
# 10                                                NaN    no
# 27                              GBRX01007139.1_3        yes
# 43                              GEMK01033802.1_2        yes
# 21                              GAZD02016917.1_2        yes
# 0                                                 NaN    no
# 22                              GBAB01027851.1_4        yes
# 49                                                NaN    no
# 42                              GEMI01026287.1_4        yes
# 15                                                NaN    no
# 47                                                NaN    no
# 26                              GBRL01010261.1_1        yes
# 8          GAKJ01010751.1_3     GAKJ01009501.1_3        yes
# 35                              GDIM01029096.1_1        yes
# 39                                                NaN    no
# 23                              GBBP01080309.1_4        yes
# 44                                                NaN    no
# 18         GAVA02016919.1_3     GAVA02016920.1_3        yes

# %%
df.groupby('oskar').count()
# Out:
#        tsa  organism  oskar_sequence
# oskar
# no      20        20               0
# yes     30        30              30

# %% [markdown]
# Not find in our Insect Genome table :
# 1. Anopheles aquasalis
# 1.Anopheles quadrimaculatus
# 1. Arachnocampa luminosa
# 1. Bombylius major
# 1. Corethrella appendiculata
# 1. Culex tarsalis
# 1. Culicoides sonorensis
# 1. Drosophila malerkotliana
# 1. Drosophila montana
# 1. Drosophila serrata
# 1. Liogma simplicicornis
# 1. Lipara lucens
# 1. Pedicia vetusta
# 1. Sitodiplosis mosellana
# 1. Triarthria setipennis
