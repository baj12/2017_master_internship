# %% [markdown]
# # taskTwo
# ## Analyzing HMM results
#
# _Date: 04/09/2017_

# %%
import pandas as pd

# %%
df = pd.read_table('/home/savy/Documents/utr_evolution_result/oskar_result.csv')

# %%
len(df)
# Out:
# 63

# %%
df.set_index('tsa')
df.sort_values('organism')
# Out:
#        tsa                    organism  osk lotus oskar  \
# 41  GCLM.1            Aedes albopictus  yes   yes    no
# 42  GCZT.1            Aedes albopictus  yes   yes   yes
# 39  GBVY.1         Anopheles aquasalis   no    no    no
# 18  GAMD.1         Anopheles aquasalis  yes   yes   yes
# 3   GACZ.1         Anopheles aquasalis   no   yes    no
# 38  GBTE.1   Anopheles quadrimaculatus  yes   yes   yes
# 47  GDKS.1          Anopheles sinensis  yes   yes    no
# 32  GBEO.1          Anopheles sinensis  yes   yes    no
# 10  GAFE.1          Anopheles sinensis  yes   yes    no
# 31  GBBQ.1          Anopheles sinensis   no   yes    no
# 48  GDQV.1       Arachnocampa luminosa  yes   yes    no
# 40  GBXI.1       Bactrocera cucurbitae  yes   yes   yes
# 49  GDRP.1         Bactrocera dorsalis   no   yes    no
# 52  GEEA.1         Bactrocera dorsalis  yes   yes   yes
# 14  GAKP.1         Bactrocera dorsalis  yes   yes    no
# 45  GDHF.1        Bactrocera latifrons  yes   yes   yes
# ...

# %%
df.groupby(['oskar','osk','lotus']).count()
# Out:
#                  tsa  organism  oskar_sequence
# oskar osk lotus
# no    no  no      10        10               0
#           yes      8         8               0
#       yes no       2         2               0
#           yes     26        26               0
# yes   yes yes     17        17              17

# %% [markdown]
# Not found in our Insect Genome table :
# 1. Anopheles aquasalis
# 1. Anopheles quadrimaculatus
# 1. Arachnocampa luminosa
# 1. Bombylius major
# 1. Corethrella appendiculata
# 1. Culex tarsalis
# 1. Culicoides sonorensis
# 1. Drosophila malerkotliana
# 1. Drosophila montana
# 1. Drosophila serrata
# 1. Liogma simplicicornis
# 1. Lipara lucens
# 1. Pedicia vetusta
# 1. Sitodiplosis mosellana
# 1. Triarthria setipennis
