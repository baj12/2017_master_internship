# %% [markdown]
# # task_One
# ## Python parser to have a clean output of Exonerate
# _Date: 03/16/2017

# %%
import sys
import os
import re

# %%
pathgff = "/home/savandara/Documents/Internship/2017_master_internship/exonerateCleaner/gff_test.gff"
f = open(pathgff)
allLines = [x.strip() for x in f.readlines()]
f.close()

# %%
for line in allLines[2:]:

		if re.match(r'^#.*',line) is not None :
			allLines.remove(line)

# %%
allLines[2:]
# Out:
# ['NC_004354.4\texonerate:protein2genome:local\tgene\t1775682\t1783751\t3375\t+\t.\tgene_id 1 ; sequence sp|Q9NII1|ADAR_DROME ; gene_orientation +',
#  'NC_004354.4\texonerate:protein2genome:local\tcds\t1775682\t1775738\t.\t+\t.',
#  'NC_004354.4\texonerate:protein2genome:local\texon\t1775682\t1775738\t.\t+\t.\tinsertions 0 ; deletions 0',
#  'NC_004354.4\texonerate:protein2genome:local\tsplice5\t1775739\t1775740\t.\t+\t.\tintron_id 1 ; splice_site "GT"',
#  'NC_004354.4\texonerate:protein2genome:local\tintron\t1775739\t1778611\t.\t+\t.\tintron_id 1',
#  'NC_004354.4\texonerate:protein2genome:local\tsplice3\t1778610\t1778611\t.\t+\t.\tintron_id 0 ; splice_site "AG"',
#  'NC_004354.4\texonerate:protein2genome:local\tcds\t1778612\t1778699\t.\t+\t.',
#  'NC_004354.4\texonerate:protein2genome:local\texon\t1778612\t1778699\t.\t+\t.\tinsertions 0 ; deletions 0',
#  'NC_004354.4\texonerate:protein2genome:local\tsplice5\t1778700\t1778701\t.\t+\t.\tintron_id 2 ; splice_site "GT"',
# ...
