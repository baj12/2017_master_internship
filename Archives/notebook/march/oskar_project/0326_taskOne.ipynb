# %% [markdown]
# # task_One
# ## Building dataframe with Protein number and EST number
# _Date: 03/26/2017_

# %%
import pandas as pd

df = pd.read_csv('/home/savandara/Documents/Internship/2017_master_internship/genomeDownloader/curated_InsectGenomesInfos.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-a2d4eb7c4b7b> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('/home/savandara/Documents/Internship/2017_master_internship/genomeDownloader/curated_InsectGenomesInfos.csv')
#
# ...

# %%
df
# Out:
#                            Species name     Order name     Family name  \
# 0                 Catajapyx aquilonaris        Diplura       Japygidae
# 1                     Orchesella cincta     Collembola   Entomobryidae
# 2               Zootermopsis nevadensis      Blattodea     Termopsidae
# 3                Nasutitermes exitiosus      Blattodea      Termitidae
# 4                   Blattella germanica      Blattodea      Ectobiidae
# 5            Pediculus humanus corporis   Phthiraptera     Pediculidae
# 6                   Isoperla grammatica     Plecoptera      Perlodidae
# 7               Amphinemura sulcicollis     Plecoptera      Nemouridae
# 8                   Limnephilus lunatus    Trichoptera   Limnephilidae
# 9            Frankliniella occidentalis   Thysanoptera       Thripidae
# 10                 Mengenilla moldrzyki   Strepsiptera   Mengenillidae
# 11                      Ephemera danica  Ephemeroptera     Ephemeridae
# ...

# %%
i = 0
for species in df.index :
    if df["Protein annotations"][species] == "Yes" :
        print (species, df["Accession number"][species])
        
i
# Out:
# 2 GCA_000696155.1
# 5 GCA_000006295.1
# 45 GCA_001263275.1
# 46 GCA_001276565.1
# 51 GCA_001483705.1
# 63 GCA_001594115.1
# 64 GCA_000188075.1
# 65 GCA_000204515.1
# 66 GCA_000147195.1
# 67 GCA_001045655.1
# 69 GCA_001594045.1
# 71 GCA_001594065.1
# 72 GCA_000611835.1
# 73 GCA_001594075.1
# 76 GCA_001594055.1
# 77 GCA_000147175.1
# 82 GCA_001272555.1
# 85 GCA_900005825.1
# 110 GCA_000209185.1
# 113 GCA_000211455.3
# 114 GCA_000005575.1
# 129 GCA_000005135.1
# 130 GCA_000005155.1
# 136 GCA_000005975.1
# 137 GCA_000004125.1
# 144 GCA_000005925.1
# 147 GCA_000005115.1
# 155 GCA_000005195.1
# 157 GCA_000005175.1
# 201 GCA_001298355.1
# 203 GCA_001298345.1
# 215 GCA_000235995.1
# 230 GCA_001266575.1
# 232 GCA_000346045.2
# 234 GCA_001443705.1
# 236 GCA_000002335.3
# 0

# %%
import
# Out:
#                      Species name  Order name  Family name  Accession number  \
# Protein annotations
# No                            210         210          210               210
# Yes                            36          36           36                36
#
#                      Oskar presence  GeneBank annotations  GFF3 annotations  \
# Protein annotations
# No                               31                   210               210
# Yes                              14                    36                36
#
#                      Genomic fasta file  RNA fasta file  TO DO
# Protein annotations
# No                                  210             210    210
# Yes                                  36              36     36

# %%
from Bio import Entrez, SeqIO
Entrez.email = 'savandara.besse@gmail.com'

# %%
handle = Entrez.esearch(db="nucest" id="Amphinemura sulcicollis")
record = Entrez.read(handle)
# Out:
#   File "<ipython-input-20-c2b03f49b995>", line 1
#     handle = Entrez.esearch(db="nucest" term="Amphinemura sulcicollis")
#                                            ^
# SyntaxError: invalid syntax
