# %% [markdown]
# # task_One
# ## Finding Orders and Families numbers for insects
#
# Date: 03/10/2017

# %%
'''
From build_insectGenomesInfos.py
'''

import pandas as pd
pathcsv="/home/savandara/Documents/Internship/2017_master_internship/genomeDownloader/curated_insectGenomesInfos.csv"

df = pd.read_csv(pathcsv) 
df
# Out:
#      Species id                            Species name  Family id  \
# 0        884341          Heliconius numata tarapotensis      33415
# 1        144034                   Pogonomyrmex barbatus      36668
# 2          7220                       Drosophila erecta       7214
# 3          7222                    Drosophila grimshawi       7214
# 4          7225           Scaptodrosophila lebanonensis       7214
# 5        248311            Heliconius melpomene aglaope      33415
# 6          7227                 Drosophila melanogaster       7214
# 7          7229                      Drosophila miranda       7214
# 8         77166                 Dendroctonus ponderosae       7042
# 9          7385                    Neobellieria bullata       7381
# 10       104452                     Operophtera brumata      82593
# 11       252483                   Paracoccus marginatus      30190
# 12        50550                         Priacma serrata      50548
# ...

# %%
result = df.groupby(["Order name", "Family name", "Species name"]).count()
result
# Out:
#                                                                Species id  \
# Order name   Family name   Species name
# Blattodea    Ectobiidae    Blattella germanica                          1
#              Termitidae    Nasutitermes exitiosus                       1
#              Termopsidae   Zootermopsis nevadensis                      1
# Coleoptera   Buprestidae   Agrilus planipennis                          1
#              Cerambycidae  Anoplophora glabripennis                     1
#              Chrysomelidae Leptinotarsa decemlineata                    1
#              Cupedidae     Priacma serrata                              1
#              Curculionidae Dendroctonus ponderosae                      1
#                            Hypothenemus hampei                          1
#              Nitidulidae   Aethina tumida                               1
#              Scarabaeidae  Onthophagus taurus                           1
# ...

# %% [markdown]
# ## Proposition of a model organism for each order
#
# - Order: Blattodea $\rightarrow$ Family number: 3 $\Rightarrow$ __Meta HMM sur 3 ?__
# - Order: Coleoptera $\rightarrow$ Family number: 8 $\Rightarrow$ __Meta HMM sur 4 ?__ On a un organisme modèle
# - Order: Collembola $\rightarrow$ Family number: 1 $\Rightarrow$ __Orchesella cincta__
# - Order: Diplura $\rightarrow$ Family number: 1 $\Rightarrow$ __Catajapyx aquilonaris__
# - Order: Diptera $\rightarrow$ Family number: 23 $\Rightarrow$ __Drosophila Melanogaster__
# - Order: Ephemeroptera $\rightarrow$ Family number: 2 $\Rightarrow$ __Meta HMM sur 2 ?__
# - Order: Hemiptera $\rightarrow$ Family number: 12 $\Rightarrow$ __Meta HMM sur 6 ?__
# - Order: Hymenoptera $\rightarrow$ Family number: 15 $\Rightarrow$ __Meta HMM sur abeille, guepe et fourmi ?__ Nassonia visperis
# - Order: Lepidoptera $\rightarrow$ Family number: 12 $\Rightarrow$ __Meta HMM sur 6 ?__ Papillon
# - Order: Odonata $\rightarrow$ Family number: 1 $\Rightarrow$ __Ladona fulva__
# - Order: Orthoptera $\rightarrow$ Family number: 1 $\Rightarrow$ __Locusta migratoria__
# - Order: Phasmatodea $\rightarrow$ Family number: 1 $\Rightarrow$ __Timema cristinae__
# - Order: Phthiraptera $\rightarrow$ Family number: 1 $\Rightarrow$ __Pediculus humanus corporis__
# - Order: Plecoptera $\rightarrow$ Family number: 2 $\Rightarrow$ __Meta HMM sur 2 ?__
# - Order: Strepsiptera $\rightarrow$ Family number: 1 $\Rightarrow$ __Mengenilla
# - Order: Thysanoptera $\rightarrow$ Family number: 1 $\Rightarrow$ __Frankliniella occidentalis__
# - Order: Trichoptera $\rightarrow$ Family number: 1 $\Rightarrow$ __Limnephilus lunatus__
#
# ## TO DO
# Determine if these genomes have already a GFF file or not (to pass augustus-one step)
