# %% [markdown]
# # task_One
# ## Understand the several files in Genome Assembly folder
# _Date: 03/22/2017_

# %% [markdown]
# ### *_protein.faa.gz file
#
# > - FASTA format of the accessioned protein products annotated on the genome  assembly
# > - The FASTA title is formatted as sequence accession.version plus
#        description.
#
# - We can find Oskar !!

# %% [markdown]
# ### *_genomic.gbff.gz file
#
# > - GenBank flat file format of the genomic sequence(s) in the assembly
# > - This file includes both the genomic sequence and the CONTIG description
#
# - Can be directly used by __Augustus__

# %% [markdown]
# ### *_genomic.gff.gz file
#
# > - Annotation of the genomic sequence(s) in Generic Feature Format Version 3
# > - (GFF3). Sequence identifiers are provided as accession.version.
#
# - Can be used by __Augustus__ after converting this file in genbank file

# %% [markdown]
# ### *_genomic.fna.gz file
#
# > - FASTA format of the genomic sequence(s) in the assembly. Repetitive
# sequences in eukaryotes are masked to lower-case (see below).
# > - The FASTA title is formatted as sequence accession.version plus description.
#
# - Used for __gene prediction (GeneMark)__ and __protein alignments (Exonerate)__ in case of we don't have gene annotations (genomic.gff)
# - Used to convert annotations.gff into annotations.gb

# %% [markdown]
# ### *_rna.fna.gz file
#
# > - FASTA format of accessioned RNA products annotated on the genome assembly; Provided for RefSeq assemblies as relevant (Note, RNA and mRNA products are not instantiated as a separate accessioned record in GenBank but are provided for some RefSeq genomes, most notably the eukaryotes.)
# > - The FASTA title is provided as sequence accession.version plus description.
#
# - _Not used there but can be referenced in our csv file_

# %%
import pandas as pd
import re

# %%
inputpath = "/home/savandara/Documents/Internship/2017_master_internship/genomeDownloader/curated_insectGenomesInfos.csv"
df = pd.read_csv(inputpath)
dfi = df.sort_values(["Order id", "Family id"], ascending=[0,1])[['Order name', 'Family name', 'Species name', 'Accession number']]
dfi
# Out:
#         Order name     Family name                        Species name  \
# 229        Diplura       Japygidae               Catajapyx aquilonaris
# 160     Collembola   Entomobryidae                   Orchesella cincta
# 42       Blattodea     Termopsidae             Zootermopsis nevadensis
# 62       Blattodea      Termitidae              Nasutitermes exitiosus
# 215      Blattodea      Ectobiidae                 Blattella germanica
# 204   Phthiraptera     Pediculidae          Pediculus humanus corporis
# 180     Plecoptera      Perlodidae                 Isoperla grammatica
# 48      Plecoptera      Nemouridae             Amphinemura sulcicollis
# 77     Trichoptera   Limnephilidae                 Limnephilus lunatus
# 165   Thysanoptera       Thripidae          Frankliniella occidentalis
# 63    Strepsiptera   Mengenillidae                Mengenilla moldrzyki
# 224  Ephemeroptera     Ephemeridae                     Ephemera danica
# 124  Ephemeroptera        Baetidae                      Baetis rhodani
# 69       Hemiptera     Aleyrodidae                      Bemisia tabaci
# 91       Hemiptera       Lygaeidae                Oncopeltus fasciatus
# 23       Hemiptera      Reduviidae                   Rhodnius prolixus
# 25       Hemiptera       Aphididae                      Myzus persicae
# 31       Hemiptera       Aphididae                     Diuraphis noxia
# 101      Hemiptera       Aphididae                 Acyrthosiphon pisum
# 69   GCA_001854935.1
# 91   GCA_000696205.1
# 23   GCA_000181055.3
# 25   GCA_001856785.1
# 31   GCA_001938505.1
# 101  GCA_000142985.2
# 214  GCA_001460545.1
# 230  GCA_001663875.1
# 175  GCA_000695645.1
# 198  GCA_000475195.1
# 59   GCA_000696855.1
# 11   GCA_900065295.1
# 67   GCA_900060175.1
# 73   GCA_900050545.1
# 79   GCA_900064475.1
# 82   GCA_900064465.1
# 102  GCA_900080175.1
# ..               ...
# 127  GCA_001486705.1
# 141  GCA_001510915.1
# 169  GCA_001486645.1
# 176  GCA_001485725.1
# 185  GCA_001486725.1
# 192  GCA_001486605.1
# 193  GCA_001485905.1
# 202  GCA_001486125.1
# 212  GCA_000326025.1
# 227  GCA_001486085.1
# 232  GCA_001486685.1
# 241  GCA_000716385.1
# 107  GCA_001278395.1
# 205  GCA_000325945.1
# 10   GCA_001266575.1
# 33   GCA_000636095.1
# 8    GCA_000346045.2
# 147  GCA_001012855.1
# 109  GCA_001443705.1
# 201  GCA_000648695.1
# 200  GCA_000002335.3
# 86   GCA_000500325.1
# 233  GCA_000390285.1
# 114  GCA_000699045.1
# 12   GCA_000281835.1
# 156  GCA_001412225.1
# 39   GCA_001937115.1
# 126  GCA_002009905.1
# 159  GCA_000516895.1
# 84   GCA_000376725.1
#
# [246 rows x 4 columns]

# %%
nameFolder_list = []

for genome in dfi['Accession number'] :
    regExpr = re.findall(r'^([A-Z]{3})_([0-9]{9})', genome)[0]
    nameFolder = regExpr[0]+regExpr[1]
    nameFolder_list.append(nameFolder)
    
# nameFolder_list

# %%
'''
Use of $ in RegExpr
'''
ex = 'blablabla*_genomic.gbff.gz'

rep = re.findall(r'(_genomic.gbff.gz)$', ex)
rep
# Out:
# ['_genomic.gbff.gz']

# %%
infos = [{'GCA_000472065.2_Anop_sine_SINENSIS_V1': {'Protein annotations': 'No', 'TO DO': 'Use Augustus', 'Accession number': 'GCA_000472065.2', 'RNA fasta file': 'No', 'GeneBank annotations': 'Yes', 'Genomic fasta file': 'No', 'GFF3 annotations': 'Yes'}}, {'GCA_001014415.1_ASM101441v1': {'Protein annotations': 'No', 'TO DO': 'Use Augustus', 'Accession number': 'GCA_001014415.1', 'RNA fasta file': 'No', 'GeneBank annotations': 'Yes', 'Genomic fasta file': 'No', 'GFF3 annotations': 'Yes'}}, {'GCA_001676475.1_iso_kmer61.contig': {'Protein annotations': 'No', 'TO DO': 'Use Augustus', 'Accession number': 'GCA_001676475.1', 'RNA fasta file': 'No', 'GeneBank annotations': 'Yes', 'Genomic fasta file': 'No', 'GFF3 annotations': 'Yes'}}]

# %%
infos_df = []
for Dict in infos :
    for key in Dict.keys():
        infos_df.append(Dict[key])
infos_df
# Out:
# [{'Accession number': 'GCA_000472065.2',
#   'GFF3 annotations': 'Yes',
#   'GeneBank annotations': 'Yes',
#   'Genomic fasta file': 'No',
#   'Protein annotations': 'No',
#   'RNA fasta file': 'No',
#   'TO DO': 'Use Augustus'},
#  {'Accession number': 'GCA_001014415.1',
#   'GFF3 annotations': 'Yes',
#   'GeneBank annotations': 'Yes',
#   'Genomic fasta file': 'No',
#   'Protein annotations': 'No',
#   'RNA fasta file': 'No',
#   'TO DO': 'Use Augustus'},
#  {'Accession number': 'GCA_001676475.1',
#   'GFF3 annotations': 'Yes',
#   'GeneBank annotations': 'Yes',
#   'Genomic fasta file': 'No',
#   'Protein annotations': 'No',
#   'RNA fasta file': 'No',
#   'TO DO': 'Use Augustus'}]

# %%
dfm = pd.DataFrame(infos_df)
dfm = dfm[['Accession number','Protein annotations','GeneBank annotations','GFF3 annotations','Genomic fasta file','RNA fasta file','TO DO']]
dfm
# Out:
#   Accession number Protein annotations GeneBank annotations GFF3 annotations  \
# 0  GCA_000472065.2                  No                  Yes              Yes
# 1  GCA_001014415.1                  No                  Yes              Yes
# 2  GCA_001676475.1                  No                  Yes              Yes
#
#   Genomic fasta file RNA fasta file         TO DO
# 0                 No             No  Use Augustus
# 1                 No             No  Use Augustus
# 2                 No             No  Use Augustus

# %%
dff = pd.merge(dfi, dfm, how='inner', on=['Accession number'], sort=False, suffixes=('_x', '_y'), copy=True, indicator=False)

# %%
dff = dff.set_index('Species name')

# %%
dff
# Out:
#                      Order name    Family name Accession number  \
# Species name
# Isoperla grammatica  Plecoptera     Perlodidae  GCA_001676475.1
# Anopheles sinensis      Diptera      Culicidae  GCA_000472065.2
# Phortica variegata      Diptera  Drosophilidae  GCA_001014415.1
#
#                     Protein annotations GeneBank annotations GFF3 annotations  \
# Species name
# Isoperla grammatica                  No                  Yes              Yes
# Anopheles sinensis                   No                  Yes              Yes
# Phortica variegata                   No                  Yes              Yes
#
#                     Genomic fasta file RNA fasta file         TO DO
# Species name
# Isoperla grammatica                 No             No  Use Augustus
# Anopheles sinensis                  No             No  Use Augustus
# Phortica variegata                  No             No  Use Augustus

# %%
print("Species name,")
for column in dff.columns:
    if column == "TO DO":
        print(column,'\n')
    else :
        print(column,',')
# Out:
# Species name,
# Order name ,
# Family name ,
# Accession number ,
# Protein annotations ,
# GeneBank annotations ,
# GFF3 annotations ,
# Genomic fasta file ,
# RNA fasta file ,
# TO DO

# %%
for species in dff.index:
    print(species, ',')
    for column in dff.columns:
        if column == 'TO DO':
            print(dff[column][species],'\n')
        else:
            print(dff[column][species],',')
# Out:
# Isoperla grammatica ,
# Plecoptera ,
# Perlodidae ,
# GCA_001676475.1 ,
# No ,
# Yes ,
# Yes ,
# No ,
# No ,
# Use Augustus
#
# Anopheles sinensis ,
# Diptera ,
# Culicidae ,
# GCA_000472065.2 ,
# No ,
# Yes ,
# Yes ,
# No ,
# No ,
# Use Augustus
#
# Phortica variegata ,
# Diptera ,
# Drosophilidae ,
# GCA_001014415.1 ,
# No ,
# Yes ,
# Yes ,
# No ,
# No ,
# Use Augustus
